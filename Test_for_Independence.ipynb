# %% [markdown]
# <a href="https://colab.research.google.com/github/sugu2307/stclaret/blob/main/Test_for_Independence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Is there a relationship between days and smokers/ non-smokers? Test with alpha = 0.05

# %%
tips_new = tips.groupby(["day", "smoker"]).count()
tips_new.head()
# Out:
# <ipython-input-3-30a9850fcc8a>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips_new = tips.groupby(["day", "smoker"]).count()
#              total_bill  tip  sex  time  size
# day  smoker
# Thur Yes             17   17   17    17    17
#      No              45   45   45    45    45
# Fri  Yes             15   15   15    15    15
#      No               4    4    4     4     4
# Sat  Yes             42   42   42    42    42

# %%
df = tips_new[["size"]]
df.head()
# Out:
#              size
# day  smoker
# Thur Yes       17
#      No        45
# Fri  Yes       15
#      No         4
# Sat  Yes       42

# %%
df_new = pd.pivot_table(df, index = "day", columns = "smoker", values = "size")
df_new.head()
# Out:
# <ipython-input-5-d34ea4f1deac>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df_new = pd.pivot_table(df, index = "day", columns = "smoker", values = "size")
# smoker   Yes    No
# day
# Thur    17.0  45.0
# Fri     15.0   4.0
# Sat     42.0  45.0
# Sun     19.0  57.0

# %%
stats.chi2_contingency(df_new)
# Out:
# Chi2ContingencyResult(statistic=np.float64(25.787216672396262), pvalue=np.float64(1.0567572499836523e-05), dof=3, expected_freq=array([[23.63114754, 38.36885246],
#        [ 7.24180328, 11.75819672],
#        [33.15983607, 53.84016393],
#        [28.96721311, 47.03278689]]))

# %% [markdown]
# pvalue is less than 0.05 --> We reject H0 and accept H1 that there is a relationship between days and smokers/ non-smokers.
